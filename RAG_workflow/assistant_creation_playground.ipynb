# %%
from VG_assistant_manager import get_list_of_assistants, list_uploaded_documents

# %%
import openai
from config import MODEL_NAME, OPENAI_KEY

# Initialize OpenAI API
openai.api_key = OPENAI_KEY

print(openai.api_key)
# Out:
# sk-MbifPFZR0fT6x6G--y2RY7sDi7JTKJ3mn46PGoGAIqT3BlbkFJQmlfkT28636lfxxop_BJTygRCqCXwhOOHWmfCg104A

# %%
from openai import OpenAI
# Initialize OpenAI API
openai.api_key = OPENAI_KEY
client = OpenAI(api_key= OPENAI_KEY)

# %%
# CREATING THE ASSISTANT
from VG_assistant_manager import create_openai_assistant

create_openai_assistant()
# Out:
# Creating OpenAI assistant with model gpt-4o-2024-08-06...
# Assistant created with ID: asst_RWi2VFF19yCuUdv8A4Ro14Js
# Vector store created with ID: vs_18MrTh86C8zi9aMuQ62Qr6Ow
# Batch processing of files started. This may take a few minutes...
# Batch processing completed.
# Status: completed
# File counts: FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2)
# Assistant asst_RWi2VFF19yCuUdv8A4Ro14Js updated with Vector Store vs_18MrTh86C8zi9aMuQ62Qr6Ow.
# ...

# %%
# GET LIST OF ASSISTANTS
get_list_of_assistants()
# Out:
# [Assistant(id='asst_RWi2VFF19yCuUdv8A4Ro14Js', created_at=1730650884, description=None, instructions='You are an gaming design data analyst who is responsible for going through a corpus of research papers on video games solving relevant problems. Your role is to scan row by row of the input data to find information form the huge corpus of data and return it in the template formats given to you.', metadata={}, model='gpt-4o-2024-08-06', name=None, object='assistant', tools=[FileSearchTool(type='file_search', file_search={'ranking_options': {'ranker': 'default_2024_08_21', 'score_threshold': 0.0}})], response_format='auto', temperature=1.0, tool_resources=ToolResources(code_interpreter=None, file_search=ToolResourcesFileSearch(vector_store_ids=['vs_18MrTh86C8zi9aMuQ62Qr6Ow'])), top_p=1.0)]

# %%
# GET LIST OF DOCUMENTS
list_uploaded_documents()
# Out:
# ID: file-fpGHM9Ag0ULppuILo7SA2fbW, Filename: Video_Game_Attributes.docx, Purpose: assistants
# ID: file-ZRDvWFdkMOvOQj7c2Rl5Eeo5, Filename: Detailed_Instructions.docx, Purpose: assistants

# %%
# GET LIST OF VECTOR STORES
vector_stores = client.beta.vector_stores.list()
print(vector_stores)
# Out:
# SyncCursorPage[VectorStore](data=[VectorStore(id='vs_18MrTh86C8zi9aMuQ62Qr6Ow', created_at=1730650884, file_counts=FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2), last_active_at=1730650888, metadata={}, name='Video Game research vector store', object='vector_store', status='completed', usage_bytes=48036, expires_after=None, expires_at=None)], object='list', first_id='vs_18MrTh86C8zi9aMuQ62Qr6Ow', last_id='vs_18MrTh86C8zi9aMuQ62Qr6Ow', has_more=False)

# %%
# DELETEING VECTOR STORE

# deleted_vector_store = client.beta.vector_stores.delete(
#   vector_store_id="vs_HwiQjGlRYSI081sETq5KUyfZ"
# )
# print(deleted_vector_store)

# DELETEING FILE
# deleted_file = client.files.delete("file-jTVaUUuHOJYBdzTs53xXPExw")
# print(deleted_file)

# %%
# DELETING ASSISTANT
## response = client.beta.assistants.delete("asst_Eb2tDzsJrxPKHLp2aZcC6mde")
## print(response)
